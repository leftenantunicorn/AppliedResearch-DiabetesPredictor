# %%
    import os
    import sys
    import numpy as np
    import pandas as pd
    import sklearn.preprocessing as pp
    from sklearn.cross_validation import train_test_split
    from sklearn import svm, linear_model, naive_bayes
    import simplejson as json
    from sklearn.model_selection import GridSearchCV
    from sklearn.pipeline import make_union, make_pipeline
    from sklearn.preprocessing import FunctionTransformer
    from sklearn.base import BaseEstimator, TransformerMixin
    from sklearn.model_selection import GridSearchCV

    # from https://medium.com/@literallywords/sklearn-identity-transformer-fcc18bac0e98
    class IdentityTransformer(BaseEstimator, TransformerMixin):
        def __init__(self):
            pass

        def fit(self, input_array, y=None):
            return self

        def transform(self, input_array, y=None):
            return input_array * 1

    # Get training data
    df = pd.read_csv('pima-data.csv')
    
    float_formatter = lambda x: "%.2f" % x
    np.set_printoptions(formatter={'float_kind':float_formatter})
    
    feature_col_names_fullset = ['num_preg', 'glucose_conc', 'diastolic_bp', 'thickness', 'insulin', 'bmi', 'diab_pred', 'age']
    feature_col_names = ['num_preg', 'glucose_conc', 'bmi', 'diab_pred']
    predicted_class_names = ['diabetes']
    
    x = df[feature_col_names].values
    y = df[predicted_class_names].values
    
    fill_0 = pp.Imputer(missing_values=0, strategy="mean", axis=0)
    scaler = pp.StandardScaler()
    
    def get_invalid0_cols(df):
        return df[['glucose_conc', 'diastolic_bp', 'thickness', 'insulin', 'bmi', 'diab_pred', 'age']]

    def get_valid0_cols(df):
        return df[['num_preg']]

    vec = make_union(*[
        make_pipeline(FunctionTransformer(get_valid0_cols, validate=False), IdentityTransformer()),
        make_pipeline(FunctionTransformer(get_invalid0_cols, validate=False), fill_0),
        #make_pipeline(FunctionTransformer(get_num_cols, validate=False), scaler)
    ])
    
    x = vec.fit_transform(df)
    #x = scaler.fit_transform(x)
    
    split_test_size = 0.20
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=split_test_size, random_state=73) 

    scaler = pp.StandardScaler()

    # Train model - GridSearch Optimized NuSVC
    def getNuSVCModel():
        global x_train
        global x_test
        x_train = scaler.fit_transform(x_train)
        x_test = scaler.fit_transform(x_test)
        nuSvc_model = svm.NuSVC()
        parameters = {
            'kernel':('linear', 'rbf'), 
            'nu': np.arange( 0.01, 0.7, 0.01 ).tolist(),
            'gamma': np.arange( 0.01, 3.0+0.0, 0.1 ).tolist()}
        clf = GridSearchCV(nuSvc_model, parameters)
        clf.fit(x_train, y_train.ravel()) 
        return clf


    clf = getNuSVCModel()
    
    
    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(x_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# Best parameters set found on development set:
#
# {'nu': 0.47000000000000003, 'gamma': 0.01, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.347 (+/-0.079) for {'nu': 0.01, 'gamma': 0.01, 'kernel': 'linear'}
# 0.471 (+/-0.278) for {'nu': 0.02, 'gamma': 0.01, 'kernel': 'linear'}
# 0.373 (+/-0.181) for {'nu': 0.03, 'gamma': 0.01, 'kernel': 'linear'}
# 0.513 (+/-0.294) for {'nu': 0.04, 'gamma': 0.01, 'kernel': 'linear'}
# 0.537 (+/-0.116) for {'nu': 0.05, 'gamma': 0.01, 'kernel': 'linear'}
# 0.484 (+/-0.116) for {'nu': 0.060000000000000005, 'gamma': 0.01, 'kernel': 'linear'}
# 0.565 (+/-0.216) for {'nu': 0.06999999999999999, 'gamma': 0.01, 'kernel': 'linear'}
# 0.477 (+/-0.227) for {'nu': 0.08, 'gamma': 0.01, 'kernel': 'linear'}
# 0.498 (+/-0.323) for {'nu': 0.09, 'gamma': 0.01, 'kernel': 'linear'}
# 0.546 (+/-0.290) for {'nu': 0.09999999999999999, 'gamma': 0.01, 'kernel': 'linear'}
# 0.585 (+/-0.257) for {'nu': 0.11, 'gamma': 0.01, 'kernel': 'linear'}
# 0.493 (+/-0.228) for {'nu': 0.12, 'gamma': 0.01, 'kernel': 'linear'}
# 0.541 (+/-0.226) for {'nu': 0.13, 'gamma': 0.01, 'kernel': 'linear'}
# 0.601 (+/-0.198) for {'nu': 0.14, 'gamma': 0.01, 'kernel': 'linear'}
# 0.695 (+/-0.067) for {'nu': 0.15000000000000002, 'gamma': 0.01, 'kernel': 'linear'}
# 0.638 (+/-0.119) for {'nu': 0.16, 'gamma': 0.01, 'kernel': 'linear'}
# 0.612 (+/-0.185) for {'nu': 0.17, 'gamma': 0.01, 'kernel': 'linear'}
# 0.546 (+/-0.112) for {'nu': 0.18000000000000002, 'gamma': 0.01, 'kernel': 'linear'}
# 0.616 (+/-0.159) for {'nu': 0.19, 'gamma': 0.01, 'kernel': 'linear'}
# 0.554 (+/-0.352) for {'nu': 0.2, 'gamma': 0.01, 'kernel': 'linear'}
# 0.503 (+/-0.301) for {'nu': 0.21000000000000002, 'gamma': 0.01, 'kernel': 'linear'}
# 0.572 (+/-0.210) for {'nu': 0.22, 'gamma': 0.01, 'kernel': 'linear'}
# 0.454 (+/-0.116) for {'nu': 0.23, 'gamma': 0.01, 'kernel': 'linear'}
# 0.534 (+/-0.254) for {'nu': 0.24000000000000002, 'gamma': 0.01, 'kernel': 'linear'}
# 0.459 (+/-0.251) for {'nu': 0.25, 'gamma': 0.01, 'kernel': 'linear'}
# 0.663 (+/-0.044) for {'nu': 0.26, 'gamma': 0.01, 'kernel': 'linear'}
# 0.485 (+/-0.169) for {'nu': 0.27, 'gamma': 0.01, 'kernel': 'linear'}
# 0.516 (+/-0.168) for {'nu': 0.28, 'gamma': 0.01, 'kernel': 'linear'}
# 0.604 (+/-0.187) for {'nu': 0.29000000000000004, 'gamma': 0.01, 'kernel': 'linear'}
# 0.523 (+/-0.195) for {'nu': 0.3, 'gamma': 0.01, 'kernel': 'linear'}
# 0.604 (+/-0.081) for {'nu': 0.31, 'gamma': 0.01, 'kernel': 'linear'}
# 0.500 (+/-0.242) for {'nu': 0.32, 'gamma': 0.01, 'kernel': 'linear'}
# 0.621 (+/-0.125) for {'nu': 0.33, 'gamma': 0.01, 'kernel': 'linear'}
# 0.542 (+/-0.279) for {'nu': 0.34, 'gamma': 0.01, 'kernel': 'linear'}
# 0.577 (+/-0.208) for {'nu': 0.35000000000000003, 'gamma': 0.01, 'kernel': 'linear'}
# 0.458 (+/-0.357) for {'nu': 0.36000000000000004, 'gamma': 0.01, 'kernel': 'linear'}
# 0.651 (+/-0.172) for {'nu': 0.37, 'gamma': 0.01, 'kernel': 'linear'}
# 0.533 (+/-0.261) for {'nu': 0.38, 'gamma': 0.01, 'kernel': 'linear'}
# 0.694 (+/-0.088) for {'nu': 0.39, 'gamma': 0.01, 'kernel': 'linear'}
# 0.679 (+/-0.065) for {'nu': 0.4, 'gamma': 0.01, 'kernel': 'linear'}
# 0.721 (+/-0.028) for {'nu': 0.41000000000000003, 'gamma': 0.01, 'kernel': 'linear'}
# 0.715 (+/-0.076) for {'nu': 0.42000000000000004, 'gamma': 0.01, 'kernel': 'linear'}
# 0.739 (+/-0.042) for {'nu': 0.43, 'gamma': 0.01, 'kernel': 'linear'}
# 0.736 (+/-0.027) for {'nu': 0.44, 'gamma': 0.01, 'kernel': 'linear'}
# 0.743 (+/-0.017) for {'nu': 0.45, 'gamma': 0.01, 'kernel': 'linear'}
# 0.609 (+/-0.289) for {'nu': 0.46, 'gamma': 0.01, 'kernel': 'linear'}
# 0.783 (+/-0.059) for {'nu': 0.47000000000000003, 'gamma': 0.01, 'kernel': 'linear'}
# 0.725 (+/-0.052) for {'nu': 0.48000000000000004, 'gamma': 0.01, 'kernel': 'linear'}
# 0.752 (+/-0.035) for {'nu': 0.49, 'gamma': 0.01, 'kernel': 'linear'}
# 0.756 (+/-0.039) for {'nu': 0.5, 'gamma': 0.01, 'kernel': 'linear'}
# 0.751 (+/-0.039) for {'nu': 0.51, 'gamma': 0.01, 'kernel': 'linear'}
# 0.756 (+/-0.040) for {'nu': 0.52, 'gamma': 0.01, 'kernel': 'linear'}
# 0.756 (+/-0.046) for {'nu': 0.53, 'gamma': 0.01, 'kernel': 'linear'}
# 0.764 (+/-0.070) for {'nu': 0.54, 'gamma': 0.01, 'kernel': 'linear'}
# 0.772 (+/-0.070) for {'nu': 0.55, 'gamma': 0.01, 'kernel': 'linear'}
# 0.767 (+/-0.066) for {'nu': 0.56, 'gamma': 0.01, 'kernel': 'linear'}
# 0.770 (+/-0.062) for {'nu': 0.5700000000000001, 'gamma': 0.01, 'kernel': 'linear'}
# 0.775 (+/-0.043) for {'nu': 0.5800000000000001, 'gamma': 0.01, 'kernel': 'linear'}
# 0.777 (+/-0.052) for {'nu': 0.59, 'gamma': 0.01, 'kernel': 'linear'}
# 0.780 (+/-0.041) for {'nu': 0.6, 'gamma': 0.01, 'kernel': 'linear'}
# 0.777 (+/-0.047) for {'nu': 0.61, 'gamma': 0.01, 'kernel': 'linear'}
# 0.772 (+/-0.034) for {'nu': 0.62, 'gamma': 0.01, 'kernel': 'linear'}
# 0.777 (+/-0.042) for {'nu': 0.63, 'gamma': 0.01, 'kernel': 'linear'}
# 0.775 (+/-0.041) for {'nu': 0.64, 'gamma': 0.01, 'kernel': 'linear'}
# 0.767 (+/-0.018) for {'nu': 0.65, 'gamma': 0.01, 'kernel': 'linear'}
# 0.765 (+/-0.027) for {'nu': 0.66, 'gamma': 0.01, 'kernel': 'linear'}
# 0.767 (+/-0.028) for {'nu': 0.67, 'gamma': 0.01, 'kernel': 'linear'}
# 0.762 (+/-0.025) for {'nu': 0.68, 'gamma': 0.01, 'kernel': 'linear'}
# 0.759 (+/-0.024) for {'nu': 0.6900000000000001, 'gamma': 0.01, 'kernel': 'linear'}
# 0.353 (+/-0.089) for {'nu': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.358 (+/-0.022) for {'nu': 0.02, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.383 (+/-0.049) for {'nu': 0.03, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.477 (+/-0.274) for {'nu': 0.04, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.627 (+/-0.239) for {'nu': 0.05, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.590 (+/-0.147) for {'nu': 0.060000000000000005, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.694 (+/-0.021) for {'nu': 0.06999999999999999, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.590 (+/-0.055) for {'nu': 0.08, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.673 (+/-0.024) for {'nu': 0.09, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.616 (+/-0.073) for {'nu': 0.09999999999999999, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.624 (+/-0.132) for {'nu': 0.11, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.637 (+/-0.070) for {'nu': 0.12, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.603 (+/-0.118) for {'nu': 0.13, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.593 (+/-0.067) for {'nu': 0.14, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.640 (+/-0.063) for {'nu': 0.15000000000000002, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.660 (+/-0.127) for {'nu': 0.16, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.640 (+/-0.067) for {'nu': 0.17, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.627 (+/-0.097) for {'nu': 0.18000000000000002, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.663 (+/-0.034) for {'nu': 0.19, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.635 (+/-0.122) for {'nu': 0.2, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.678 (+/-0.019) for {'nu': 0.21000000000000002, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.682 (+/-0.034) for {'nu': 0.22, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.658 (+/-0.055) for {'nu': 0.23, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.687 (+/-0.032) for {'nu': 0.24000000000000002, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.689 (+/-0.094) for {'nu': 0.25, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.643 (+/-0.054) for {'nu': 0.26, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.651 (+/-0.043) for {'nu': 0.27, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.673 (+/-0.106) for {'nu': 0.28, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.676 (+/-0.019) for {'nu': 0.29000000000000004, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.712 (+/-0.047) for {'nu': 0.3, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.710 (+/-0.062) for {'nu': 0.31, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.728 (+/-0.056) for {'nu': 0.32, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.705 (+/-0.054) for {'nu': 0.33, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.736 (+/-0.026) for {'nu': 0.34, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.746 (+/-0.018) for {'nu': 0.35000000000000003, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.736 (+/-0.031) for {'nu': 0.36000000000000004, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.744 (+/-0.019) for {'nu': 0.37, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.752 (+/-0.039) for {'nu': 0.38, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.749 (+/-0.027) for {'nu': 0.39, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.767 (+/-0.017) for {'nu': 0.4, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.749 (+/-0.016) for {'nu': 0.41000000000000003, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.756 (+/-0.012) for {'nu': 0.42000000000000004, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.756 (+/-0.014) for {'nu': 0.43, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.754 (+/-0.026) for {'nu': 0.44, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.754 (+/-0.031) for {'nu': 0.45, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.759 (+/-0.026) for {'nu': 0.46, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.761 (+/-0.027) for {'nu': 0.47000000000000003, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.759 (+/-0.016) for {'nu': 0.48000000000000004, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.759 (+/-0.015) for {'nu': 0.49, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.756 (+/-0.013) for {'nu': 0.5, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.756 (+/-0.027) for {'nu': 0.51, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.762 (+/-0.032) for {'nu': 0.52, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.757 (+/-0.031) for {'nu': 0.53, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.757 (+/-0.038) for {'nu': 0.54, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.757 (+/-0.032) for {'nu': 0.55, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.761 (+/-0.034) for {'nu': 0.56, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.764 (+/-0.034) for {'nu': 0.5700000000000001, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.774 (+/-0.031) for {'nu': 0.5800000000000001, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.775 (+/-0.027) for {'nu': 0.59, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.775 (+/-0.027) for {'nu': 0.6, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.780 (+/-0.034) for {'nu': 0.61, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.777 (+/-0.038) for {'nu': 0.62, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.774 (+/-0.036) for {'nu': 0.63, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.774 (+/-0.030) for {'nu': 0.64, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.770 (+/-0.034) for {'nu': 0.65, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.770 (+/-0.034) for {'nu': 0.66, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.767 (+/-0.024) for {'nu': 0.67, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.765 (+/-0.027) for {'nu': 0.68, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.770 (+/-0.028) for {'nu': 0.6900000000000001, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.347 (+/-0.079) for {'nu': 0.01, 'gamma': 0.11, 'kernel': 'linear'}
# 0.471 (+/-0.278) for {'nu': 0.02, 'gamma': 0.11, 'kernel': 'linear'}
# 0.373 (+/-0.181) for {'nu': 0.03, 'gamma': 0.11, 'kernel': 'linear'}
# 0.513 (+/-0.294) for {'nu': 0.04, 'gamma': 0.11, 'kernel': 'linear'}
# 0.537 (+/-0.116) for {'nu': 0.05, 'gamma': 0.11, 'kernel': 'linear'}
# 0.484 (+/-0.116) for {'nu': 0.060000000000000005, 'gamma': 0.11, 'kernel': 'linear'}
# 0.565 (+/-0.216) for {'nu': 0.06999999999999999, 'gamma': 0.11, 'kernel': 'linear'}
# 0.477 (+/-0.227) for {'nu': 0.08, 'gamma': 0.11, 'kernel': 'linear'}
# 0.498 (+/-0.323) for {'nu': 0.09, 'gamma': 0.11, 'kernel': 'linear'}
# 0.546 (+/-0.290) for {'nu': 0.09999999999999999, 'gamma': 0.11, 'kernel': 'linear'}
# 0.585 (+/-0.257) for {'nu': 0.11, 'gamma': 0.11, 'kernel': 'linear'}
# 0.493 (+/-0.228) for {'nu': 0.12, 'gamma': 0.11, 'kernel': 'linear'}
# 0.541 (+/-0.226) for {'nu': 0.13, 'gamma': 0.11, 'kernel': 'linear'}
# 0.601 (+/-0.198) for {'nu': 0.14, 'gamma': 0.11, 'kernel': 'linear'}
# 0.695 (+/-0.067) for {'nu': 0.15000000000000002, 'gamma': 0.11, 'kernel': 'linear'}
# 0.638 (+/-0.119) for {'nu': 0.16, 'gamma': 0.11, 'kernel': 'linear'}
# 0.612 (+/-0.185) for {'nu': 0.17, 'gamma': 0.11, 'kernel': 'linear'}
# 0.546 (+/-0.112) for {'nu': 0.18000000000000002, 'gamma': 0.11, 'kernel': 'linear'}
# 0.616 (+/-0.159) for {'nu': 0.19, 'gamma': 0.11, 'kernel': 'linear'}
# 0.554 (+/-0.352) for {'nu': 0.2, 'gamma': 0.11, 'kernel': 'linear'}
# 0.503 (+/-0.301) for {'nu': 0.21000000000000002, 'gamma': 0.11, 'kernel': 'linear'}
# 0.572 (+/-0.210) for {'nu': 0.22, 'gamma': 0.11, 'kernel': 'linear'}
# 0.454 (+/-0.116) for {'nu': 0.23, 'gamma': 0.11, 'kernel': 'linear'}
# 0.534 (+/-0.254) for {'nu': 0.24000000000000002, 'gamma': 0.11, 'kernel': 'linear'}
# 0.459 (+/-0.251) for {'nu': 0.25, 'gamma': 0.11, 'kernel': 'linear'}
# 0.663 (+/-0.044) for {'nu': 0.26, 'gamma': 0.11, 'kernel': 'linear'}
# 0.485 (+/-0.169) for {'nu': 0.27, 'gamma': 0.11, 'kernel': 'linear'}
# 0.516 (+/-0.168) for {'nu': 0.28, 'gamma': 0.11, 'kernel': 'linear'}
# 0.604 (+/-0.187) for {'nu': 0.29000000000000004, 'gamma': 0.11, 'kernel': 'linear'}
# 0.523 (+/-0.195) for {'nu': 0.3, 'gamma': 0.11, 'kernel': 'linear'}
# 0.604 (+/-0.081) for {'nu': 0.31, 'gamma': 0.11, 'kernel': 'linear'}
# 0.500 (+/-0.242) for {'nu': 0.32, 'gamma': 0.11, 'kernel': 'linear'}
# 0.621 (+/-0.125) for {'nu': 0.33, 'gamma': 0.11, 'kernel': 'linear'}
# 0.542 (+/-0.279) for {'nu': 0.34, 'gamma': 0.11, 'kernel': 'linear'}
# 0.577 (+/-0.208) for {'nu': 0.35000000000000003, 'gamma': 0.11, 'kernel': 'linear'}
# 0.458 (+/-0.357) for {'nu': 0.36000000000000004, 'gamma': 0.11, 'kernel': 'linear'}
# 0.651 (+/-0.172) for {'nu': 0.37, 'gamma': 0.11, 'kernel': 'linear'}
# 0.533 (+/-0.261) for {'nu': 0.38, 'gamma': 0.11, 'kernel': 'linear'}
# 0.694 (+/-0.088) for {'nu': 0.39, 'gamma': 0.11, 'kernel': 'linear'}
# 0.679 (+/-0.065) for {'nu': 0.4, 'gamma': 0.11, 'kernel': 'linear'}
# 0.721 (+/-0.028) for {'nu': 0.41000000000000003, 'gamma': 0.11, 'kernel': 'linear'}
# 0.715 (+/-0.076) for {'nu': 0.42000000000000004, 'gamma': 0.11, 'kernel': 'linear'}
# 0.739 (+/-0.042) for {'nu': 0.43, 'gamma': 0.11, 'kernel': 'linear'}
# 0.736 (+/-0.027) for {'nu': 0.44, 'gamma': 0.11, 'kernel': 'linear'}
# 0.743 (+/-0.017) for {'nu': 0.45, 'gamma': 0.11, 'kernel': 'linear'}
# 0.609 (+/-0.289) for {'nu': 0.46, 'gamma': 0.11, 'kernel': 'linear'}
# 0.783 (+/-0.059) for {'nu': 0.47000000000000003, 'gamma': 0.11, 'kernel': 'linear'}
# 0.725 (+/-0.052) for {'nu': 0.48000000000000004, 'gamma': 0.11, 'kernel': 'linear'}
# 0.752 (+/-0.035) for {'nu': 0.49, 'gamma': 0.11, 'kernel': 'linear'}
# 0.756 (+/-0.039) for {'nu': 0.5, 'gamma': 0.11, 'kernel': 'linear'}
# 0.751 (+/-0.039) for {'nu': 0.51, 'gamma': 0.11, 'kernel': 'linear'}
# 0.756 (+/-0.040) for {'nu': 0.52, 'gamma': 0.11, 'kernel': 'linear'}
# 0.756 (+/-0.046) for {'nu': 0.53, 'gamma': 0.11, 'kernel': 'linear'}
# 0.764 (+/-0.070) for {'nu': 0.54, 'gamma': 0.11, 'kernel': 'linear'}
# 0.772 (+/-0.070) for {'nu': 0.55, 'gamma': 0.11, 'kernel': 'linear'}
# 0.767 (+/-0.066) for {'nu': 0.56, 'gamma': 0.11, 'kernel': 'linear'}
# 0.770 (+/-0.062) for {'nu': 0.5700000000000001, 'gamma': 0.11, 'kernel': 'linear'}
# 0.775 (+/-0.043) for {'nu': 0.5800000000000001, 'gamma': 0.11, 'kernel': 'linear'}
# 0.777 (+/-0.052) for {'nu': 0.59, 'gamma': 0.11, 'kernel': 'linear'}
# 0.780 (+/-0.041) for {'nu': 0.6, 'gamma': 0.11, 'kernel': 'linear'}
# 0.777 (+/-0.047) for {'nu': 0.61, 'gamma': 0.11, 'kernel': 'linear'}
# 0.772 (+/-0.034) for {'nu': 0.62, 'gamma': 0.11, 'kernel': 'linear'}
# 0.777 (+/-0.042) for {'nu': 0.63, 'gamma': 0.11, 'kernel': 'linear'}
# 0.775 (+/-0.041) for {'nu': 0.64, 'gamma': 0.11, 'kernel': 'linear'}
# 0.767 (+/-0.018) for {'nu': 0.65, 'gamma': 0.11, 'kernel': 'linear'}
# 0.765 (+/-0.027) for {'nu': 0.66, 'gamma': 0.11, 'kernel': 'linear'}
# 0.767 (+/-0.028) for {'nu': 0.67, 'gamma': 0.11, 'kernel': 'linear'}
# 0.762 (+/-0.025) for {'nu': 0.68, 'gamma': 0.11, 'kernel': 'linear'}
# 0.759 (+/-0.024) for {'nu': 0.6900000000000001, 'gamma': 0.11, 'kernel': 'linear'}
# 0.676 (+/-0.063) for {'nu': 0.01, 'gamma': 0.11, 'kernel': 'rbf'}
# 0.663 (+/-0.020) for {'nu': 0.02, 'gamma': 0.11, 'kernel': 'rbf'}
# 0.686 (+/-0.015) for {'nu': 0.03, 'gamma': 0.11, 'kernel': 'rbf'}
# 0.669 (+/-0.027) for {'nu': 0.04, 'gamma': 0.11, 'kernel': 'rbf'}
# 0.671 (+/-0.023) for {'nu': 0.05, 'gamma': 0.11, 'kernel': 'rbf'}
# 0.679 (+/-0.044) for {'nu': 0.060000000000000005, 'gamma': 0.11, 'kernel': 'rbf'}
# 0.686 (+/-0.035) for {'nu': 0.06999999999999999, 'gamma': 0.11, 'kernel': 'rbf'}
# 0.684 (+/-0.031) for {'nu': 0.08, 'gamma': 0.11, 'kernel': 'rbf'}
# 0.673 (+/-0.032) for {'nu': 0.09, 'gamma': 0.11, 'kernel': 'rbf'}
# 0.664 (+/-0.032) for {'nu': 0.09999999999999999, 'gamma': 0.11, 'kernel': 'rbf'}
# 0.668 (+/-0.044) for {'nu': 0.11, 'gamma': 0.11, 'kernel': 'rbf'}
# 0.656 (+/-0.040) for {'nu': 0.12, 'gamma': 0.11, 'kernel': 'rbf'}
# 0.656 (+/-0.036) for {'nu': 0.13, 'gamma': 0.11, 'kernel': 'rbf'}
# 0.663 (+/-0.028) for {'nu': 0.14, 'gamma': 0.11, 'kernel': 'rbf'}
# 0.663 (+/-0.028) for {'nu': 0.15000000000000002, 'gamma': 0.11, 'kernel': 'rbf'}
# 0.661 (+/-0.022) for {'nu': 0.16, 'gamma': 0.11, 'kernel': 'rbf'}
# 0.666 (+/-0.022) for {'nu': 0.17, 'gamma': 0.11, 'kernel': 'rbf'}
# 0
 'gamma': 0.31000000000000005, 'kernel': 'rbf'}
# 0.721 (+/-0.024) for {'nu': 0.67, 'gamma': 0.31000000000000005, 'kernel': 'rbf'}
# 0.726 (+/-0.022) for {'nu': 0.68, 'gamma': 0.31000000000000005, 'kernel': 'rbf'}
# 0.718 (+/-0.026) for {'nu': 0.6900000000000001, 'gamma': 0.31000000000000005, 'kernel': 'rbf'}
# 0.347 (+/-0.079) for {'nu': 0.01, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.471 (+/-0.278) for {'nu': 0.02, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.373 (+/-0.181) for {'nu': 0.03, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.513 (+/-0.294) for {'nu': 0.04, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.537 (+/-0.116) for {'nu': 0.05, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.484 (+/-0.116) for {'nu': 0.060000000000000005, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.565 (+/-0.216) for {'nu': 0.06999999999999999, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.477 (+/-0.227) for {'nu': 0.08, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.498 (+/-0.323) for {'nu': 0.09, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.546 (+/-0.290) for {'nu': 0.09999999999999999, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.585 (+/-0.257) for {'nu': 0.11, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.493 (+/-0.228) for {'nu': 0.12, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.541 (+/-0.226) for {'nu': 0.13, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.601 (+/-0.198) for {'nu': 0.14, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.695 (+/-0.067) for {'nu': 0.15000000000000002, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.638 (+/-0.119) for {'nu': 0.16, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.612 (+/-0.185) for {'nu': 0.17, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.546 (+/-0.112) for {'nu': 0.18000000000000002, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.616 (+/-0.159) for {'nu': 0.19, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.554 (+/-0.352) for {'nu': 0.2, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.503 (+/-0.301) for {'nu': 0.21000000000000002, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.572 (+/-0.210) for {'nu': 0.22, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.454 (+/-0.116) for {'nu': 0.23, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.534 (+/-0.254) for {'nu': 0.24000000000000002, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.459 (+/-0.251) for {'nu': 0.25, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.663 (+/-0.044) for {'nu': 0.26, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.485 (+/-0.169) for {'nu': 0.27, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.516 (+/-0.168) for {'nu': 0.28, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.604 (+/-0.187) for {'nu': 0.29000000000000004, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.523 (+/-0.195) for {'nu': 0.3, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.604 (+/-0.081) for {'nu': 0.31, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.500 (+/-0.242) for {'nu': 0.32, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.621 (+/-0.125) for {'nu': 0.33, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.542 (+/-0.279) for {'nu': 0.34, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.577 (+/-0.208) for {'nu': 0.35000000000000003, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.458 (+/-0.357) for {'nu': 0.36000000000000004, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.651 (+/-0.172) for {'nu': 0.37, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.533 (+/-0.261) for {'nu': 0.38, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.694 (+/-0.088) for {'nu': 0.39, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.679 (+/-0.065) for {'nu': 0.4, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.721 (+/-0.028) for {'nu': 0.41000000000000003, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.715 (+/-0.076) for {'nu': 0.42000000000000004, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.739 (+/-0.042) for {'nu': 0.43, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.736 (+/-0.027) for {'nu': 0.44, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.743 (+/-0.017) for {'nu': 0.45, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.609 (+/-0.289) for {'nu': 0.46, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.783 (+/-0.059) for {'nu': 0.47000000000000003, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.725 (+/-0.052) for {'nu': 0.48000000000000004, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.752 (+/-0.035) for {'nu': 0.49, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# 0.756 (+/-0.039) for {'nu': 0.5, 'gamma': 0.41000000000000003, 'kernel': 'linear'}
# ...
# 0.775 (+/-0.043) for {'nu': 0.5800000000000001, 'gamma': 2.81, 'kernel': 'linear'}
# 0.777 (+/-0.052) for {'nu': 0.59, 'gamma': 2.81, 'kernel': 'linear'}
# 0.780 (+/-0.041) for {'nu': 0.6, 'gamma': 2.81, 'kernel': 'linear'}
# 0.777 (+/-0.047) for {'nu': 0.61, 'gamma': 2.81, 'kernel': 'linear'}
# 0.772 (+/-0.034) for {'nu': 0.62, 'gamma': 2.81, 'kernel': 'linear'}
# 0.777 (+/-0.042) for {'nu': 0.63, 'gamma': 2.81, 'kernel': 'linear'}
# 0.775 (+/-0.041) for {'nu': 0.64, 'gamma': 2.81, 'kernel': 'linear'}
# 0.767 (+/-0.018) for {'nu': 0.65, 'gamma': 2.81, 'kernel': 'linear'}
# 0.765 (+/-0.027) for {'nu': 0.66, 'gamma': 2.81, 'kernel': 'linear'}
# 0.767 (+/-0.028) for {'nu': 0.67, 'gamma': 2.81, 'kernel': 'linear'}
# 0.762 (+/-0.025) for {'nu': 0.68, 'gamma': 2.81, 'kernel': 'linear'}
# 0.759 (+/-0.024) for {'nu': 0.6900000000000001, 'gamma': 2.81, 'kernel': 'linear'}
# 0.640 (+/-0.011) for {'nu': 0.01, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.02, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.03, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.04, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.05, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.060000000000000005, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.06999999999999999, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.08, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.09, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.09999999999999999, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.11, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.12, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.13, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.14, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.15000000000000002, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.16, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.17, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.18000000000000002, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.19, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.2, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.21000000000000002, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.22, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.23, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.24000000000000002, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.25, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.26, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.27, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.28, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.29000000000000004, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.3, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.31, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.32, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.33, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.34, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.35000000000000003, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.36000000000000004, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.37, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.38, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.39, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.4, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.41000000000000003, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.42000000000000004, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.43, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.44, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.45, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.46, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.47000000000000003, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.48000000000000004, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.49, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.5, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.51, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.52, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.53, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.54, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.55, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.56, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.5700000000000001, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.5800000000000001, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.59, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.642 (+/-0.007) for {'nu': 0.6, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.642 (+/-0.007) for {'nu': 0.61, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.642 (+/-0.007) for {'nu': 0.62, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.642 (+/-0.007) for {'nu': 0.63, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.642 (+/-0.007) for {'nu': 0.64, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.642 (+/-0.007) for {'nu': 0.65, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.642 (+/-0.007) for {'nu': 0.66, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.642 (+/-0.007) for {'nu': 0.67, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.642 (+/-0.007) for {'nu': 0.68, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.643 (+/-0.009) for {'nu': 0.6900000000000001, 'gamma': 2.81, 'kernel': 'rbf'}
# 0.347 (+/-0.079) for {'nu': 0.01, 'gamma': 2.91, 'kernel': 'linear'}
# 0.471 (+/-0.278) for {'nu': 0.02, 'gamma': 2.91, 'kernel': 'linear'}
# 0.373 (+/-0.181) for {'nu': 0.03, 'gamma': 2.91, 'kernel': 'linear'}
# 0.513 (+/-0.294) for {'nu': 0.04, 'gamma': 2.91, 'kernel': 'linear'}
# 0.537 (+/-0.116) for {'nu': 0.05, 'gamma': 2.91, 'kernel': 'linear'}
# 0.484 (+/-0.116) for {'nu': 0.060000000000000005, 'gamma': 2.91, 'kernel': 'linear'}
# 0.565 (+/-0.216) for {'nu': 0.06999999999999999, 'gamma': 2.91, 'kernel': 'linear'}
# 0.477 (+/-0.227) for {'nu': 0.08, 'gamma': 2.91, 'kernel': 'linear'}
# 0.498 (+/-0.323) for {'nu': 0.09, 'gamma': 2.91, 'kernel': 'linear'}
# 0.546 (+/-0.290) for {'nu': 0.09999999999999999, 'gamma': 2.91, 'kernel': 'linear'}
# 0.585 (+/-0.257) for {'nu': 0.11, 'gamma': 2.91, 'kernel': 'linear'}
# 0.493 (+/-0.228) for {'nu': 0.12, 'gamma': 2.91, 'kernel': 'linear'}
# 0.541 (+/-0.226) for {'nu': 0.13, 'gamma': 2.91, 'kernel': 'linear'}
# 0.601 (+/-0.198) for {'nu': 0.14, 'gamma': 2.91, 'kernel': 'linear'}
# 0.695 (+/-0.067) for {'nu': 0.15000000000000002, 'gamma': 2.91, 'kernel': 'linear'}
# 0.638 (+/-0.119) for {'nu': 0.16, 'gamma': 2.91, 'kernel': 'linear'}
# 0.612 (+/-0.185) for {'nu': 0.17, 'gamma': 2.91, 'kernel': 'linear'}
# 0.546 (+/-0.112) for {'nu': 0.18000000000000002, 'gamma': 2.91, 'kernel': 'linear'}
# 0.616 (+/-0.159) for {'nu': 0.19, 'gamma': 2.91, 'kernel': 'linear'}
# 0.554 (+/-0.352) for {'nu': 0.2, 'gamma': 2.91, 'kernel': 'linear'}
# 0.503 (+/-0.301) for {'nu': 0.21000000000000002, 'gamma': 2.91, 'kernel': 'linear'}
# 0.572 (+/-0.210) for {'nu': 0.22, 'gamma': 2.91, 'kernel': 'linear'}
# 0.454 (+/-0.116) for {'nu': 0.23, 'gamma': 2.91, 'kernel': 'linear'}
# 0.534 (+/-0.254) for {'nu': 0.24000000000000002, 'gamma': 2.91, 'kernel': 'linear'}
# 0.459 (+/-0.251) for {'nu': 0.25, 'gamma': 2.91, 'kernel': 'linear'}
# 0.663 (+/-0.044) for {'nu': 0.26, 'gamma': 2.91, 'kernel': 'linear'}
# 0.485 (+/-0.169) for {'nu': 0.27, 'gamma': 2.91, 'kernel': 'linear'}
# 0.516 (+/-0.168) for {'nu': 0.28, 'gamma': 2.91, 'kernel': 'linear'}
# 0.604 (+/-0.187) for {'nu': 0.29000000000000004, 'gamma': 2.91, 'kernel': 'linear'}
# 0.523 (+/-0.195) for {'nu': 0.3, 'gamma': 2.91, 'kernel': 'linear'}
# 0.604 (+/-0.081) for {'nu': 0.31, 'gamma': 2.91, 'kernel': 'linear'}
# 0.500 (+/-0.242) for {'nu': 0.32, 'gamma': 2.91, 'kernel': 'linear'}
# 0.621 (+/-0.125) for {'nu': 0.33, 'gamma': 2.91, 'kernel': 'linear'}
# 0.542 (+/-0.279) for {'nu': 0.34, 'gamma': 2.91, 'kernel': 'linear'}
# 0.577 (+/-0.208) for {'nu': 0.35000000000000003, 'gamma': 2.91, 'kernel': 'linear'}
# 0.458 (+/-0.357) for {'nu': 0.36000000000000004, 'gamma': 2.91, 'kernel': 'linear'}
# 0.651 (+/-0.172) for {'nu': 0.37, 'gamma': 2.91, 'kernel': 'linear'}
# 0.533 (+/-0.261) for {'nu': 0.38, 'gamma': 2.91, 'kernel': 'linear'}
# 0.694 (+/-0.088) for {'nu': 0.39, 'gamma': 2.91, 'kernel': 'linear'}
# 0.679 (+/-0.065) for {'nu': 0.4, 'gamma': 2.91, 'kernel': 'linear'}
# 0.721 (+/-0.028) for {'nu': 0.41000000000000003, 'gamma': 2.91, 'kernel': 'linear'}
# 0.715 (+/-0.076) for {'nu': 0.42000000000000004, 'gamma': 2.91, 'kernel': 'linear'}
# 0.739 (+/-0.042) for {'nu': 0.43, 'gamma': 2.91, 'kernel': 'linear'}
# 0.736 (+/-0.027) for {'nu': 0.44, 'gamma': 2.91, 'kernel': 'linear'}
# 0.743 (+/-0.017) for {'nu': 0.45, 'gamma': 2.91, 'kernel': 'linear'}
# 0.609 (+/-0.289) for {'nu': 0.46, 'gamma': 2.91, 'kernel': 'linear'}
# 0.783 (+/-0.059) for {'nu': 0.47000000000000003, 'gamma': 2.91, 'kernel': 'linear'}
# 0.725 (+/-0.052) for {'nu': 0.48000000000000004, 'gamma': 2.91, 'kernel': 'linear'}
# 0.752 (+/-0.035) for {'nu': 0.49, 'gamma': 2.91, 'kernel': 'linear'}
# 0.756 (+/-0.039) for {'nu': 0.5, 'gamma': 2.91, 'kernel': 'linear'}
# 0.751 (+/-0.039) for {'nu': 0.51, 'gamma': 2.91, 'kernel': 'linear'}
# 0.756 (+/-0.040) for {'nu': 0.52, 'gamma': 2.91, 'kernel': 'linear'}
# 0.756 (+/-0.046) for {'nu': 0.53, 'gamma': 2.91, 'kernel': 'linear'}
# 0.764 (+/-0.070) for {'nu': 0.54, 'gamma': 2.91, 'kernel': 'linear'}
# 0.772 (+/-0.070) for {'nu': 0.55, 'gamma': 2.91, 'kernel': 'linear'}
# 0.767 (+/-0.066) for {'nu': 0.56, 'gamma': 2.91, 'kernel': 'linear'}
# 0.770 (+/-0.062) for {'nu': 0.5700000000000001, 'gamma': 2.91, 'kernel': 'linear'}
# 0.775 (+/-0.043) for {'nu': 0.5800000000000001, 'gamma': 2.91, 'kernel': 'linear'}
# 0.777 (+/-0.052) for {'nu': 0.59, 'gamma': 2.91, 'kernel': 'linear'}
# 0.780 (+/-0.041) for {'nu': 0.6, 'gamma': 2.91, 'kernel': 'linear'}
# 0.777 (+/-0.047) for {'nu': 0.61, 'gamma': 2.91, 'kernel': 'linear'}
# 0.772 (+/-0.034) for {'nu': 0.62, 'gamma': 2.91, 'kernel': 'linear'}
# 0.777 (+/-0.042) for {'nu': 0.63, 'gamma': 2.91, 'kernel': 'linear'}
# 0.775 (+/-0.041) for {'nu': 0.64, 'gamma': 2.91, 'kernel': 'linear'}
# 0.767 (+/-0.018) for {'nu': 0.65, 'gamma': 2.91, 'kernel': 'linear'}
# 0.765 (+/-0.027) for {'nu': 0.66, 'gamma': 2.91, 'kernel': 'linear'}
# 0.767 (+/-0.028) for {'nu': 0.67, 'gamma': 2.91, 'kernel': 'linear'}
# 0.762 (+/-0.025) for {'nu': 0.68, 'gamma': 2.91, 'kernel': 'linear'}
# 0.759 (+/-0.024) for {'nu': 0.6900000000000001, 'gamma': 2.91, 'kernel': 'linear'}
# 0.638 (+/-0.016) for {'nu': 0.01, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.02, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.03, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.04, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.05, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.060000000000000005, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.06999999999999999, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.08, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.09, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.09999999999999999, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.11, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.12, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.13, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.14, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.15000000000000002, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.16, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.17, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.18000000000000002, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.19, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.2, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.21000000000000002, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.22, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.23, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.24000000000000002, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.25, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.26, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.27, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.28, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.29000000000000004, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.3, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.31, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.32, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.33, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.34, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.35000000000000003, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.36000000000000004, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.37, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.38, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.39, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.4, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.41000000000000003, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.42000000000000004, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.43, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.44, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.45, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.46, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.47000000000000003, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.48000000000000004, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.49, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.5, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.51, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.52, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.53, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.54, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.55, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.56, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.638 (+/-0.016) for {'nu': 0.5700000000000001, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.5800000000000001, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.59, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.6, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.61, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.62, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.63, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.64, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.640 (+/-0.011) for {'nu': 0.65, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.642 (+/-0.013) for {'nu': 0.66, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.642 (+/-0.013) for {'nu': 0.67, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.642 (+/-0.013) for {'nu': 0.68, 'gamma': 2.91, 'kernel': 'rbf'}
# 0.642 (+/-0.013) for {'nu': 0.6900000000000001, 'gamma': 2.91, 'kernel': 'rbf'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-498c8a864e9f> in <module>()
#      98 print()
#      99 y_true, y_pred = y_test, clf.predict(x_test)
# --> 100 print(classification_report(y_true, y_pred))
#     101 print()
#
# NameError: name 'classification_report' is not defined
